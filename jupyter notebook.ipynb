# %%
begin
	using MarketData
	
	data = yahoo(:AAPL, YahooOpt(period1 = DateTime(2018, 1, 1)))
end
# Out:
# 1849×6 TimeArray{Float64, 2, Date, Matrix{Float64}} 2018-01-02 to 2025-05-09
# ┌────────────┬─────────┬─────────┬─────────┬─────────┬──────────┬───────────┐
# │            │ Open    │ High    │ Low     │ Close   │ AdjClose │ Volume    │
# ├────────────┼─────────┼─────────┼─────────┼─────────┼──────────┼───────────┤
# │ 2018-01-02 │   42.54 │  43.075 │  42.315 │  43.065 │  40.4798 │ 1.02224e8 │
# │ 2018-01-03 │ 43.1325 │ 43.6375 │   42.99 │ 43.0575 │  40.4728 │ 1.18072e8 │
# │ 2018-01-04 │  43.135 │ 43.3675 │   43.02 │ 43.2575 │  40.6608 │ 8.97384e7 │
# │ 2018-01-05 │   43.36 │ 43.8425 │ 43.2625 │   43.75 │  41.1237 │   9.464e7 │
# │ 2018-01-08 │ 43.5875 │ 43.9025 │ 43.4825 │ 43.5875 │   40.971 │ 8.22712e7 │
# │ 2018-01-09 │ 43.6375 │  43.765 │ 43.3525 │ 43.5825 │  40.9663 │  8.6336e7 │
# │ 2018-01-10 │   43.29 │  43.575 │   43.25 │ 43.5725 │  40.9569 │ 9.58396e7 │
# │ 2018-01-11 │ 43.6475 │ 43.8725 │ 43.6225 │   43.82 │  41.1895 │ 7.46708e7 │
# ...

# %%
begin
	using Plots
	Plots.plot(data.Close, label="Closing Prices", xlabel="Date", ylabel="Price (USD)")
end
